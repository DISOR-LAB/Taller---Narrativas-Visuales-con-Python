# %% [markdown]
# # Visualización de datos con Python - Summer Institute in Computational Social Science

# %% [markdown]
# # Introducción
#
# **Autor:** Sergio Daniel Sánchez Pulido
# **Carrera:** Sociólogo y Magíster en Economía de las Políticas Públicas
# **Fecha:** 2025-05-18
#
# La **visualización de datos** es mucho más que un elemento estético: es una herramienta estratégica que potencia nuestra capacidad para entender, explorar y comunicar información compleja. Entre sus principales potencialidades se incluyen:
#
# - **Exploración interactiva:** Facilita el análisis ad hoc de grandes volúmenes de datos, permitiendo filtrar, agrupar y profundizar en detalles con solo unos clics.
# - **Descubrimiento de patrones y tendencias:** Revela relaciones ocultas, pendientes, ciclos estacionales o cambios abruptos que no serían evidentes en tablas numéricas.
# - **Detección de anomalías y valores atípicos:** Permite identificar rápidamente outliers o inconsistencias en los datos, mejorando la calidad y fiabilidad de los análisis.
# - **Comunicación clara y persuasiva:** Transforma cifras en historias visuales, haciendo más accesible el mensaje tanto para audiencias técnicas como para públicos generales.
# - **Soporte a la toma de decisiones:** Un dashboard bien diseñado resume indicadores clave y facilita la evaluación de escenarios, reduciendo el riesgo y acelerando la respuesta.
# - **Fomento de la colaboración:** Comparte insights de forma visual con colegas o grupos de interés, generando un lenguaje común y alineando criterios de interpretación.
# - **Narrativa de datos:** Guiar al receptor paso a paso mediante anotaciones, highlights y transiciones fortalece la comprensión y el impacto del mensaje.
# - **Reproducibilidad y transparencia:** Al estandarizar procesos de generación de gráficos se documentan los pasos del análisis, favoreciendo la validación y auditoría de resultados.
#
# Con estas capacidades, la visualización se convierte en un aliado imprescindible para cualquier analista, investigador o gestor de políticas públicas, pues permite transformar datos crudos en conocimiento accionable.
#
# Como sabréis, las personas aprenden fácilmente con objetos visuales. Nos resulta fácil extraer conclusiones de forma visual. Por ello, la visualización de datos es una herramienta que debe servir como motivación y sobre todo para proveer un mecanismo de comunicación más rápido y efectivo.
#
# En general, la visualización de datos, como técnica, se sirve de la representación visual para hacer que nuestros documentos o presentaciones sean más atractivos.
#
# En este sentido, la visualización nos sirve para ofrecer una visión general, concisa y rápida de la información que gestionamos. Nuestra audiencia puede así comprender fácilmente los resultados e incluso transmitirlos de forma efectiva a otros.
#
#
# Por ello, la visualización, la representación gráfica de datos e información tiene una serie de ventajas:
#
# * **Mejora de la capacidad de procesamiento de información**. El contenido visual se procesa mucho más rápido y de forma más fácil que, por ejemplo, un texto. Nuestro cerebro es muy bueno encontrando patrones en un objeto visual. Por lo tanto, el grado de comprensión se incrementa cuando se utiliza la visualización como técnica de comunicación.
# * **Incremento en la capacidad de aprendizaje**. Como se ha comentado anteriormente, las personas aprendemos de forma visual. Bueno, en realidad, el 65% de la población puede aprender de esta manera. Por eso, las técnicas de visualización de datos nos ayudan a comprender de forma sencilla y rápida la información que se presenta.
# * **Facilita la identificación de patrones y tendencias en los datos**. En lugar de ofrecer un documento de texto, se pueden crear gráficos que resuman una gran cantidad de datos facilitando la identificación de ideas y tendencias clave.
# * **Incremento de la productividad**. En base al punto anterior, en lugar de examinar un documento suuuper largo o revisar un conjunto de valores, con la visualización se puede obtener una visión general de nuestro dominio en una solo vistazo.
#
# Sin embargo, también es importante señalar algunas cuestiones no tan ventajosas de las técnicas de
# visualización:
#
# * **Gráficos que son incomprensibles**. A veces no es sencillo simplificar la complejidad de un análisis en un conjunto de gráficos. Tal vez, se necesitaría algo más, alguna explicación, algo para enriquecer y completar nuestros gráficos.
# * **Puntos de vista diferentes**. Las personas somos diferentes y puede ocurrir que ante el mismo gráfico se puedan obtener diferentes interpretaciones. Por ello, es necesario asegurar que nuestros gráficos transmiten el mismo mensaje y que son comprensibles para toda nuestra audiencia.
# * **Falta de guía o ayuda**. Algunas personas pueden no entender la información que se está representando. Somos humanos y nuestro medio de comunicación habitual es la lengua hablada, por lo que es normal incluir un mecanismo de verbalización, una explicación adicional del gráfico, para garantizar que se entiende adecuadamente.
# * **Falta de información**. A veces, los números, el análisis o los resultados de este son demasiados complicados y, nuevamente, no es tan fácil crear un gráfico que sirva para simplificar una explicación. La visualización es una herramienta excelente para mejorar la comprensión de los
# datos, pero se deben utilizar otros recursos complementarios.
#
# Por ello, voy a introducir ahora una clasificación de los tipos o categorías de gráficos así como su principal aplicación.
#
# * **Comparación**. Este tipo de gráfico se utiliza principalmente para ordenar y comparar diferentes valores. Se puede, por ejemplo, mostrar una comparación en el tiempo (como evoluciona una variable) utilizando un gráfico de línea, barras o columnas.
# * **Distribución**. Este tipo de gráfico se utiliza para realizar una comparación de diferentes valores en un determinado eje. Como ejemplos, se puede realizar un histograma para una variable o un gráfico de dispersión para dos variables.
# * **Composición**. Este tipo de gráfico se utiliza para crear visualizaciones y hacer comparaciones entre las diferentes partes de un todo. Como ejemplos, se puede utilizar un gráfico en forma de pastel o circular o un gráfico de columnas apiladas para ver cómo una variable determinada contribuye a un valor total.
# * **Relación**. Este tipo de gráfico se puede utilizar para mostrar relaciones entre dos o más variables. Por ejemplo, el gráfico de dispersión anterior es un ejemplo, y un gráfico de burbujas es otra posibilidad para mostrar las relaciones entre 3 variables.
# * **Otro tipo de gráfico**s. Dependiendo de la herramienta de hoja de cálculo, se pueden encontrar otros tipos de gráficos como mapas de calor, mapas geográficos, etc. Todos ellos representan una opción fabulosa para presentar datos en diferentes contextos (y principalmente en función de nuestros objetivos y audiencia).
#
# Pero, sobre todo lo que es importante es:
#
# 1.  entender qué tipo de datos se están manejando y
# 2.  que se pretende representar para finalmente seleccionar el tipo de gráfico adecuado.
#
# ![alt text](https://img.labnol.org/di/data-chart-type.png)
#
# Para datos multivariantes existen diferentes posibilidades, entre ellos:
#
# * Chernoff: ver esta demo https://gnarmis.github.io/chernoff-faces/ (en Python no hay biblioteca oficial, si en R)
# * Otro ejemplo para el crimen: https://flowingdata.com/2010/08/31/how-to-visualize-data-with-cartoonish-faces/crime-chernoff-faces-by-state-edited-2/
# * Glyphs: https://medium.com/@mlardelli/beyond-chernoff-faces-multivariate-visualization-with-metaphoric-3d-glyphs-7414b811fb35
#
#
# ![alt text](https://i1.wp.com/flowingdata.com/wp-content/uploads/2010/08/Crime-Chernoff-Faces-by-state-edited1.gif?fit=954%2C1330&ssl=1)

# %% [markdown]
# # Visualización con: Matplotlib (estática)

# %% [markdown]
# Matplotlib es una biblioteca de visualización 2D de Python que genera gráficos de distinto tipo, de alta calidad e interactivos. En general, se puede ver como un canvas en el cual dibujar.

# %% [markdown]
# ## Modelo
#
# A continuación, se presentan los elementos de un gráfico en matplotlib. Estos elementos serán los que se podrán configurar con los parámetros en las funciones de plotting.
#
# ![alt text](https://matplotlib.org/_images/anatomy.png)

# %% [markdown]
# ## Elementos de un gráfico
#
# * Figure: The whole figure. The figure keeps track of **all the child Axes**, a smattering of 'special' artists (titles, figure legends, etc), and the canvas. (Don't worry too much about the canvas, it is crucial as it is the object that actually does the drawing to get you your plot, but as the user it is more-or-less invisible to you).** A figure can have any number of Axes**, but to be useful should have at least one.
#
# * Axes: This is what you think of as **'a plot'**, it is the region of the image with the data space. **A given figure can contain many Axes, but a given Axes object can only be in one Figure**. The Axes contains two (or three in the case of 3D) Axis objects (be aware of the difference between Axes and Axis) which take care of the data limits (the data limits can also be controlled via set via the set_xlim() and set_ylim() Axes methods). Each Axes has a title (set via set_title()), an x-label (set via set_xlabel()), and a y-label set via set_ylabel()).  The Axes class and it's member functions are the primary entry point to working with the OO interface.
#
# * Axis: **These are the number-line-like objects**. They take care of setting the graph limits and generating the ticks (the marks on the axis) and ticklabels (strings labeling the ticks). The location of the ticks is determined by a Locator object and the ticklabel strings are formatted by a Formatter. The combination of the correct Locator and Formatter gives very fine control over the tick locations and labels.
#
# * Artist: Basically **everything you can see on the figure is an artist** (even the Figure, Axes, and Axis objects). This includes Text objects, Line2D objects, collection objects, Patch objects ... (you get the idea). When the figure is rendered, all of the artists are drawn to the canvas. Most Artists are tied to an Axes; such an Artist cannot be shared by multiple Axes, or moved from one to another.
#
# Ver más información sobre layout aquí: https://matplotlib.org/tutorials/intermediate/tight_layout_guide.html

# %% [markdown]
# ## Entrada de datos
#
# Todas las funciones de visualización esperan np.array o np.ma.masked_array como entrada.
#
# Las clases similares a una matriz, como los frames de datos de pandas y np.matrix pueden o no funcionar. Es mejor convertirlos en objetos np.array antes de trazar.

# %%
import numpy as np
import pandas as pandas
a = pandas.DataFrame(np.random.rand(4,5), columns = list('abcde'))
a_asndarray = a.values

# %%
b = np.matrix([[1,2],[3,4]])
b_asarray = np.asarray(b)

# %% [markdown]
# ## Ejemplos

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2, 100)

#Se introducen dos dimensiones

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Simple Plot")

plt.legend()

plt.show()

# %% [markdown]
# ## Elementos de la figura

# %%
#Se puede ver el grid para dibujar.

fig, ax = plt.subplots(nrows=2, ncols=4)

# %%
fig.get_size_inches()
# Out:
# array([6.4, 4.8])

# %%
#fig.set_facecolor('.9')
#ax.set_facecolor('.7')
#fig

# %%
#spines = ax.spines
#spines

# %%
#spine_left = spines['left']
#spine_left.set_position(('outward', -100))
#spine_left.set_linewidth(5)

#spine_bottom = spines['bottom']
#spine_bottom.set_visible(False)
#fig

# %%
#ax.xaxis.grid(True, which='major', linewidth=2, color='black', linestyle='--')
#ax.xaxis.set_ticks([.2, .4, .55, .93])
#ax.xaxis.set_label_text('X Axis', family='Verdana', fontsize=15)

#ax.set_ylabel('Y Axis', family='Calibri', fontsize=20)
#ax.set_yticks([.1, .9])
#ax.set_yticklabels(['point 1', 'point 9'], rotation=45)
#fig

# %%
#ax.xaxis.properties()

# %%
#Reset
#ax.clear()
plt.clf()
plt.cla()
plt.close()

# %% [markdown]
# ### Ejemplos sencillos

# %%
import matplotlib.pyplot as plt

# Dibujar una seno
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x));

# %%
# Dibujar un scatter
x = np.random.normal(size=500)
y = np.random.normal(size=500)
plt.scatter(x, y);

# %%
# Mostrar imágenes usando imshow
# Hay que tener en cuenta que el origen por defecto está arriba a la izquierda

x = np.linspace(1, 12, 100)
y = x[:, np.newaxis]

im = y * np.sin(x) * np.cos(y)
print(im.shape)

plt.imshow(im);
# Out:
# (100, 100)

# %%
# Hacer un diagrama de curvas de nivel (contour plot)
# origen aquí está abajo a la izquierda
plt.contour(im);

# %%
# El modo "notebook" en lugar de inline permite que los plots sean interactivos
#%matplotlib notebook
# Plot en 3D
from mpl_toolkits.mplot3d import Axes3D
ax = plt.axes(projection='3d')
xgrid, ygrid = np.meshgrid(x, y.ravel())
ax.plot_surface(xgrid, ygrid, im, cmap=plt.cm.viridis, cstride=2, rstride=2, linewidth=0);

# %% [markdown]
# * Ver más ejemplos aquí: https://matplotlib.org/gallery.html

# %%
# %load http://matplotlib.org/mpl_examples/pylab_examples/ellipse_collection.py
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.collections import EllipseCollection

x = np.arange(10)
y = np.arange(15)
X, Y = np.meshgrid(x, y)

XY = np.hstack((X.ravel()[:, np.newaxis], Y.ravel()[:, np.newaxis]))

ww = X/10.0
hh = Y/15.0
aa = X*9


fig, ax = plt.subplots()

ec = EllipseCollection(ww, hh, aa, units='x', offsets=XY,
                       transOffset=ax.transData)
ec.set_array((X + Y).ravel())
ax.add_collection(ec)
ax.autoscale_view()
ax.set_xlabel('X')
ax.set_ylabel('y')
cbar = plt.colorbar(ec)
cbar.set_label('X+Y')
plt.show()

# %% [markdown]
# ## Guardar figura

# %%
#fig, ax = plt.subplots()
#print(fig.canvas.get_supported_filetypes())
# fig.savefig('name.png', transparent=False, dpi=80, bbox_inches="tight")

# %% [markdown]
# #Visualización con: Seaborn (estática)
#
# Seaborn es una biblioteca de visualización de datos de Python basada en matplotlib. Proporciona una interfaz de alto nivel para dibujar gráficos estadísticos atractivos e informativos.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
print(sns.__version__)
# %matplotlib inline
sns.set(style="darkgrid")
tips = sns.load_dataset("tips")
# Out:
# 0.13.2

# %%
df = pd.DataFrame()

df['x'] = random.sample(range(1, 100), 25)
df['y'] = random.sample(range(1, 100), 25)

# %%
sns.lmplot(
    data=df,
    x='x',
    y='y',
    fit_reg=False
)

# %%
sns.kdeplot(df.y)
# Out:
# <Axes: xlabel='y', ylabel='Density'>

# %%
sns.kdeplot(
    data=df,
    x='y',
    y='x'
)
# Out:
# <Axes: xlabel='y', ylabel='x'>

# %%
sns.distplot(df.x)
# Out:
# /var/folders/cy/gjg9tdvn4636nfn4bl10381w0000gn/T/ipykernel_83295/791942802.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.x)
# <Axes: xlabel='x', ylabel='Density'>

# %%
plt.hist(df.x, alpha=.3)
sns.rugplot(df.x);

# %%
sns.boxplot([df.y, df.x])
# Out:
# <Axes: >

# %%
sns.heatmap([df.y, df.x], annot=True, fmt="d")
# Out:
# <Axes: >

# %% [markdown]
# * Categorías

# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")

sns.violinplot(x = "total_bill", data=tips)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

iris = sns.load_dataset("iris")

sns.swarmplot(x="species", y="petal_length", data=iris)

plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#sns.set_context("paper", font_scale=3, rc={"font.size":8,"axes.labelsize":5})

iris = sns.load_dataset("iris")

sns.swarmplot(x="species", y="petal_length", data=iris)

plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
import seaborn as snsb

titanic = sns.load_dataset("titanic")

g = sns.catplot(
    x="class",
    y="survived",
    hue="sex",
    col="sex",            # separa por columna
    data=titanic,
    kind="bar",
    palette="muted"
)
plt.show()

# %% [markdown]
# * Ejemplo real (ya en Pandas)
#
# **Dataset:**
#
# This archive contains 2075259 measurements gathered in a house located in Sceaux (7km of Paris, France) between December 2006 and November 2010 (47 months).
#
# 1. (global_active_power*1000/60 - sub_metering_1 - sub_metering_2 - sub_metering_3) represents the active energy consumed every minute (in watt hour) in the household by electrical equipment not measured in sub-meterings 1, 2 and 3.
# 2. The dataset contains some missing values in the measurements (nearly 1,25% of the rows). All calendar timestamps are present in the dataset but for some timestamps, the measurement values are missing: a missing value is represented by the absence of value between two consecutive semi-colon attribute separators. For instance, the dataset shows missing values on April 28, 2007.
#
#
# **Atributos:**
#
# 1. date: Date in format dd/mm/yyyy
# 2. time: time in format hh:mm:ss
# 3. global_active_power: household global minute-averaged active power (in kilowatt)
# 4. global_reactive_power: household global minute-averaged reactive power (in kilowatt)
# 5. voltage: minute-averaged voltage (in volt)
# 6. global_intensity: household global minute-averaged current intensity (in ampere)
# 7. sub_metering_1: energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a dishwasher, an oven and a microwave (hot plates are not electric but gas powered).
# 8. sub_metering_2: energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
# 9. sub_metering_3: energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.

# %%
import sys 
import numpy as np 
from scipy.stats import randint
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
pip install drive
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 52.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.1/216.1 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 25.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: httplib2
#     Found existing installation: httplib2 0.22.0
#     Uninstalling httplib2-0.22.0:
#       Successfully uninstalled httplib2-0.22.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/household_power_consumption.txt', sep=';', 
                 parse_dates={'dt' : ['Date', 'Time']}, infer_datetime_format=True, 
                 low_memory=False, na_values=['nan','?'], index_col='dt')
# Out:
# /var/folders/cy/gjg9tdvn4636nfn4bl10381w0000gn/T/ipykernel_83295/1006154414.py:1: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/household_power_consumption.txt', sep=';',
# /var/folders/cy/gjg9tdvn4636nfn4bl10381w0000gn/T/ipykernel_83295/1006154414.py:1: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/household_power_consumption.txt', sep=';',
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[177], line 1
# ...

# %%
droping_list_all=[]
for j in range(0,7):
    if not df.iloc[:, j].notnull().all():
        droping_list_all.append(j)        
droping_list_all

# %%
for j in range(0,7):        
        df.iloc[:,j]=df.iloc[:,j].fillna(df.iloc[:,j].mean())

# %%
df.isnull().sum()

# %%
df.Global_active_power.resample('D').sum().plot(title='Global_active_power resampled al día con sum') 
plt.tight_layout()
plt.show()   

df.Global_active_power.resample('D').mean().plot(title='Global_active_power resampled al día con la media', color='red') 
plt.tight_layout()
plt.show()

# %%
r = df.Global_intensity.resample('D').agg(['mean', 'std'])
r.plot(subplots = True, title='Global_intensity resampled a nivel día y media')
plt.show()

# %%
df['Global_active_power'].resample('M').mean().plot(kind='bar')
plt.xticks(rotation=60)
plt.ylabel('Global_active_power')
plt.title('Global_active_power por mes (media al mes)')
plt.show()

# %%
df['Global_active_power'].resample('Q').mean().plot(kind='bar')
plt.xticks(rotation=60)
plt.ylabel('Global_active_power')
plt.title('Global_active_power por trimestre (media por trimestre)')
plt.show()

# %%
cols = [0, 1, 2, 3, 5, 6]
i = 1
groups=cols
values = df.resample('D').mean().values
# plot cada columna
plt.figure(figsize=(15, 10))
for group in groups:
	plt.subplot(len(cols), 1, i)
	plt.plot(values[:, group])
	plt.title(df.columns[group], y=0.75, loc='right')
	i += 1
plt.show()

# %%
df.Global_active_power.resample('M').mean().plot(kind='hist', color='r', legend=True )
df.Global_reactive_power.resample('M').mean().plot(kind='hist',color='b', legend=True)
df.Global_intensity.resample('M').mean().plot(kind='hist', color='g', legend=True)
df.Sub_metering_1.resample('M').mean().plot(kind='hist', color='y', legend=True)
plt.show()

# %%
plt.matshow(df.resample('M').mean().corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('Re-Muestreo al mes', size=15)
plt.colorbar()
plt.margins(0.02)
plt.matshow(df.resample('A').mean().corr(method='spearman'),vmax=1,vmin=-1,cmap='PRGn')
plt.title('Re-Muestreo al año', size=15)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Otro ejemplo: datos del Titanic

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import timeit

# Load dataset
titanic = sns.load_dataset('titanic')

# %%
sns.distplot(titanic.age.dropna())
sns.plt.show()
# Out:
# /var/folders/cy/gjg9tdvn4636nfn4bl10381w0000gn/T/ipykernel_83295/2274974720.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic.age.dropna())
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[155], line 2
#       1 sns.distplot(titanic.age.dropna())
# ----> 2 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
g = sns.FacetGrid(titanic, row='survived', col='class')
g.map(sns.distplot, "age")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /opt/anaconda3/lib/python3.12/site-packages/seaborn/axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.jointplot(data=titanic, x='age', y='fare', kind='reg', color='g')
plt.show()

# %%
bins = [0, 12, 17, 60, np.inf]
labels = ['child', 'teenager', 'adult', 'elder']
age_groups = pd.cut(titanic.age, bins, labels=labels)
titanic['age_group'] = age_groups
df = titanic.pivot_table(index='embark_town', columns='age_group', values='fare', aggfunc=np.median)
sns.heatmap(df, annot=True, fmt=".1f")
plt.show()
# Out:
# /var/folders/cy/gjg9tdvn4636nfn4bl10381w0000gn/T/ipykernel_83295/2334064985.py:5: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df = titanic.pivot_table(index='embark_town', columns='age_group', values='fare', aggfunc=np.median)
# /var/folders/cy/gjg9tdvn4636nfn4bl10381w0000gn/T/ipykernel_83295/2334064985.py:5: FutureWarning: The provided callable <function median at 0x107a8c360> is currently using DataFrameGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df = titanic.pivot_table(index='embark_town', columns='age_group', values='fare', aggfunc=np.median)

# %%
sns.heatmap(titanic.corr(), annot=True, fmt=".2f")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 sns.heatmap(titanic.corr(), annot=True, fmt=".2f")
#       2 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %% [markdown]
# #Visualización con: Bakeh (dinámica)
#
# A continuación, se introduce otra biblioteca que permite la visualización dinámica de datos (y generar un HTML).

# %%
"""Bokeh Visualization Template

This template is a general outline for turning your data into a 
visualization using Bokeh.
"""
# Data handling
import pandas as pd
import numpy as np

# Bokeh libraries
from bokeh.io import output_file, output_notebook
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource
from bokeh.layouts import row, column, gridplot
from bokeh.models.widgets import Tabs, Panel

# Prepare the data

# Determine where the visualization will be rendered
output_file('filename.html')  # Render to static HTML, or 
output_notebook()  # Render inline in a Jupyter Notebook

# Set up the figure(s)
fig = figure()  # Instantiate a figure() object

# Connect to and draw the data

# Organize the layout

# Preview and save 
show(fig)  # See what I made, and save if I like it
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[165], line 15
#      13 from bokeh.models import ColumnDataSource
#      14 from bokeh.layouts import row, column, gridplot
# ---> 15 from bokeh.models.widgets import Tabs, Panel
#      17 # Prepare the data
#      18
#      19 # Determine where the visualization will be rendered
#      20 output_file('filename.html')  # Render to static HTML, or
#
# ImportError: cannot import name 'Tabs' from 'bokeh.models.widgets' (/opt/anaconda3/lib/python3.12/site-packages/bokeh/models/widgets/__init__.py)

# %%
from bokeh.io import output_file
from bokeh.plotting import figure, show

output_file('output_file_test.html', title='Empty Bokeh Figure')

fig = figure()

show(fig)
# Out:
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1068', ...)
#   <div id="f5ebf8b6-950a-4974-a021-68b815a6e9a2" data-root-id="p1068" style="display: contents;"></div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1068', ...)
# python(85279) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
from bokeh.io import output_notebook
from bokeh.plotting import figure, show

output_notebook()

fig = figure()

show(fig)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c185a88d-82e8-448d-9fb4-40a069ad2da4">Loading BokehJS ...</span>
#     </div>
# WARNING:bokeh.core.validation.check:W-1000 (MISSING_RENDERERS): Plot has no renderers: figure(id='p1033', ...)
#   <div id="c29202c0-6a72-43cc-ae1f-ddd1ec398509" data-root-id="p1033" style="display: contents;"></div>

# %%
# Import reset_output (only needed once) 
from bokeh.plotting import reset_output

# Use reset_output() between subsequent show() calls, as needed
reset_output()

# %%
# Bokeh Libraries
from bokeh.io import output_file
from bokeh.plotting import figure, show

x = [1, 2, 1]
y = [1, 1, 2]

output_notebook()

fig = figure(title='Coordenadas',
             plot_height=300, plot_width=300,
             x_range=(0, 3), y_range=(0, 3),
             toolbar_location=None)


fig.circle(x=x, y=y,color='green', size=10, alpha=0.5)

show(fig)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c5cebd3c-798b-4cbb-bbf2-009088c1282e">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[173], line 10
#       6 y = [1, 1, 2]
#       8 output_notebook()
# ---> 10 fig = figure(title='Coordenadas',
#      11              plot_height=300, plot_width=300,
#      12              x_range=(0, 3), y_range=(0, 3),
#      13              toolbar_location=None)
#      16 fig.circle(x=x, y=y,color='green', size=10, alpha=0.5)
#      18 show(fig)
#
# ...

# %%
import numpy as np

from bokeh.io import output_notebook
from bokeh.plotting import figure, show

day_num = np.linspace(1, 10, 10)
daily_words = [450, 628, 488, 210, 287, 791, 508, 639, 397, 943]
cumulative_words = np.cumsum(daily_words)

output_notebook()

fig = figure(title='Progreso',
             plot_height=400, plot_width=700,
             x_axis_label='Day Number', y_axis_label='Words Written',
             x_minor_ticks=2, y_range=(0, 6000),
             toolbar_location=None)

# Días como barras verticales
fig.vbar(x=day_num, bottom=0, top=daily_words, 
         color='blue', width=0.75, 
         legend='Diario')

# Acumulación
fig.line(x=day_num, y=cumulative_words, 
         color='gray', line_width=1,
         legend='Acumulado')


fig.legend.location = 'top_left'


show(fig)

# %% [markdown]
# # Tareas
#
# 1. Cargar un dataset y visualizar diferentes tipos de datos (números, categorías, etc.). Ver ejemplos tanto en matplotlib como en seaborn.
#
#   * https://seaborn.pydata.org/examples/index.html
#
# 2. Probar ejemplos de Bokeh: https://bokeh.pydata.org/en/latest/docs/user_guide.html || https://bokeh.pydata.org/en/latest/docs/gallery.html
# 3. Probar el tutorial oficial de Bokeh: https://mybinder.org/v2/gh/bokeh/bokeh-notebooks/master?filepath=tutorial%2F00%20-%20Introduction%20and%20Setup.ipynb
# 4. Ver otros ejemplos on-line:
#   * D3.js https://d3js.org/
#   * Highcharts: https://www.highcharts.com/
#   *  Tabulae: http://www.triarilabs.com/tabulae
#   * Tableau: https://www.tableau.com/es-es

# %% [markdown]
# # Referencias
#
# * https://realpython.com/python-data-visualization-bokeh/
# * https://www.datacamp.com/community/tutorials/seaborn-python-tutorial
# * https://tryolabs.com/blog/2017/03/16/pandas-seaborn-a-guide-to-handle-visualize-data-elegantly/
